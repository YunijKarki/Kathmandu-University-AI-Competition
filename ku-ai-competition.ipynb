# %% [markdown]
# # Using Pytesseract OCR For Bounding Box Calculation

# %%
import pytesseract
from bs4 import BeautifulSoup
from PIL import Image
import os

# %%
import pandas as pd

train_df = pd.read_csv("/kaggle/input/csv-file/output_data_train.csv")
train_df.head()
# Out:
#      invoice_number  issue_date     total  \
# 0               NaN  21/08/2018     76.48
# 1               NaN         NaN       NaN
# 2           1009624  04/01/2020   1431.27
# 3           20-4500  12/01/2018  52844.80
# 4  4908291912124017         NaN   5599.00
#
#                                                table  \
# 0  Descriplion of Goods HS Tarift Packagcs quanti...
# 1                                                NaN
# 2  Summary of Charges\nPrevious Balance 6,632.88\...
# 3  descRiPTCN oTy' HR PRICE amm\nxtchen gink 'hou...
# 4  ITEM DESCRIPTION Transaction SALE DiscoU] NET ...
#
#                             title
# 0  Commercial-invoice-example.jpg
# 1                         5th.jpg
# 2  sample-voip-invoice-page-1.jpg
# 3    Sample-Invoice-printable.png
# 4             EM4uiZWVAAAIDXW.jpg

# %%
train_df.isna().sum()
# Out:
# invoice_number    13
# issue_date         4
# total              5
# table              4
# title              0
# dtype: int64

# %% [markdown]
# # IoU (Intersection Over Union) Calculation

# %%
def calculate_iou(box1, box2):
    
    # Calculate the coordinates of the intersection rectangle
    x1_inter = max(box1[0], box2[0])
    y1_inter = max(box1[1], box2[1])
    x2_inter = min(box1[2], box2[2])
    y2_inter = min(box1[3], box2[3])

    # Calculate the area of the intersection rectangle
    area_inter = max(0, x2_inter - x1_inter + 1) * max(0, y2_inter - y1_inter + 1)

    # Calculate the area of each bounding box
    area_box1 = (box1[2] - box1[0] + 1) * (box1[3] - box1[1] + 1)
    area_box2 = (box2[2] - box2[0] + 1) * (box2[3] - box2[1] + 1)

    # Calculate the area of the union of the two bounding boxes
    area_union = area_box1 + area_box2 - area_inter

    # Calculate IoU
    iou = area_inter / area_union if area_union > 0 else 0.0

    return iou

# Example usage:
box1 = [76, 344, 857, 449]
box2 = [67, 337, 831, 391]

iou_score = calculate_iou(box1, box2)
print("IoU Score:", iou_score)
# Out:
# IoU Score: 0.4092062382300206

# %%
import pandas as pd

# %% [markdown]
# # Bounding Box Calculation on Train Dataset

# %%
def bounding_box(x):
    
    folder_path = f'/kaggle/input/llm-competition/llm-competition/LLM Competition/Train Files/{x}'
    img = Image.open(folder_path)

    # Perform OCR and get hOCR output
    hocr_output = pytesseract.image_to_pdf_or_hocr(img, extension='hocr')

    # Parse the hOCR content using BeautifulSoup
    soup = BeautifulSoup(hocr_output, 'html.parser')

    # Extract bounding box information from the parsed content
    bounding_boxes = []
    for span in soup.find_all('span', class_='ocrx_word'):
        # Extract text
        extracted_text = span.get_text(strip=True)

        # Extract bounding box coordinates
        bbox = span['title'].split(';')[0].split(' ')[1:]
        bbox = [int(coord) for coord in bbox]

        bounding_boxes.append({
            'text': extracted_text,
            'bounding_box': bbox
        })
    return bounding_boxes

# # Print the results
# for entry in bounding_boxes:
#     print('Text:', entry['text'])
#     print('Bounding Box:', entry['bounding_box'])
#     print()

# %%
train_result_df = train_df['title'].apply(lambda x: bounding_box(x))

# %%
# count = 0
# for box in result_df[0]:
#     count += 1
#     print(count)
#     print(box['bounding_box'])

# target_list = ['']

target_list = ['Contact','Commercial','Here']
for bounding_box in train_result_df[0]:  #train_result_df[0] is a list of dictionary
    box = bounding_box['bounding_box']
    text = bounding_box['text']
    for target in target_list:
        if target == text:
            print(f"Text: {text} box:{box}")
# Out:
# Text: Commercial box:[398, 46, 508, 59]
# Text: Contact box:[61, 90, 105, 99]
# Text: Contact box:[61, 278, 105, 286]
# Text: Contact box:[631, 448, 675, 457]

# %% [markdown]
# # Retrieving the bounding box of the training set

# %%
def retrieve_bounding_box(x, y, z, bounding_boxes_lists):
    text_extraction_row = []
    bounding_box_extraction_row = []
    # x, y, and z are pandas Series representing columns of DataFrame
    for index, row in zip(x.index, zip(x, y, z)):  #looping through each row
        bounding_boxes = bounding_boxes_lists[index]  #updating the bounding_boxes_lists on next loop
#         print(bounding_boxes)
        target_list = [row[0], row[1], row[2]]  
    
        for bounding_box in bounding_boxes:  #result_df[0] is a list of dictionary
            box = bounding_box['bounding_box']
            text = bounding_box['text']
            for target in target_list:
                if target == text:
                    
                    text_extraction_row.append(text)
                    bounding_box_extraction_row.append(box) 
                    
                
    return text_extraction_row, bounding_box_extraction_row


result = retrieve_bounding_box(df['invoice_number'],df['total'], df['issue_date'], result_df)

if result:
    text, bounding_box = result
    text = zip(text,bounding_box)
    print(tuple(text))
else:
    print("No matching bounding box found.")
# Out:
# ()

# %% [markdown]
# # Bounding Box prediction process of test dataset

# %%
test_df = pd.read_csv("/kaggle/input/output-data-csv/output_data_test.csv")

# %%
test_df.head()
# Out:
#   invoice_number  issue_date      total  \
# 0          22011  01/08/2020     436.45
# 1        4631508  13/05/2013    1445.99
# 2            NaN  05/02/2022        NaN
# 3     To00000001  10/10/2020  712000.00
# 4            NaN  19/11/2020    7000.00
#
#                                                table  \
# 0  Date Services Hours Rates Amount\n08/01/2020 A...
# 1  Line No_ Line No_ Description Shipped (USD) (U...
# 2                                                NaN
# 3  ITEM NAME QTy PRICE{ DISCOUNT/ GST AMOUNT UNIT...
# 4  Particulars Quantity Rate Amount\nRepairs and ...
#
#                                 title
# 0                        mceclip2.png
# 1                              p1.jpg
# 2  Commercial-Invoice-Template-19.jpg
# 3                   image-414 (1).png
# 4                 service-invoice.jpg

# %%
import numpy as np

test_df.insert(loc = 1, column = 'invoice_number_bbox' , value = np.nan)
test_df.insert(loc = 3, column = 'issue_date_bbox' , value = np.nan)
test_df.insert(loc = 5, column = 'total_bbox' , value = np.nan)

# %%
test_df.head()
# test_add_bbox_df.drop('invoice_number_bbox', axis = 'columns', inplace = True)
# Out:
#   invoice_number  invoice_number_bbox  issue_date  issue_date_bbox      total  \
# 0          22011                  NaN  01/08/2020              NaN     436.45
# 1        4631508                  NaN  13/05/2013              NaN    1445.99
# 2            NaN                  NaN  05/02/2022              NaN        NaN
# 3     To00000001                  NaN  10/10/2020              NaN  712000.00
# 4            NaN                  NaN  19/11/2020              NaN    7000.00
#
#    total_bbox                                              table  \
# 0         NaN  Date Services Hours Rates Amount\n08/01/2020 A...
# 1         NaN  Line No_ Line No_ Description Shipped (USD) (U...
# 2         NaN                                                NaN
# 3         NaN  ITEM NAME QTy PRICE{ DISCOUNT/ GST AMOUNT UNIT...
# 4         NaN  Particulars Quantity Rate Amount\nRepairs and ...
#
#                                 title
# 0                        mceclip2.png
# 1                              p1.jpg
# 2  Commercial-Invoice-Template-19.jpg
# 3                   image-414 (1).png
# 4                 service-invoice.jpg

# %%
# df.drop??

# %%
def bounding_box(x):
    
    folder_path = f'/kaggle/input/llm-competition/llm-competition/LLM Competition/Test Files/{x}'
    img = Image.open(folder_path)

    # Perform OCR and get hOCR output
    hocr_output = pytesseract.image_to_pdf_or_hocr(img, extension='hocr')

    # Parse the hOCR content using BeautifulSoup
    soup = BeautifulSoup(hocr_output, 'html.parser')

    # Extract bounding box information from the parsed content
    bounding_boxes = []
    for span in soup.find_all('span', class_='ocrx_word'):
        # Extract text
        extracted_text = span.get_text(strip=True)

        # Extract bounding box coordinates
        bbox = span['title'].split(';')[0].split(' ')[1:]
        bbox = [int(coord) for coord in bbox]

        bounding_boxes.append({
            'text': extracted_text,
            'bounding_box': bbox
        })
    return bounding_boxes

# # Print the results
# for entry in bounding_boxes:
#     print('Text:', entry['text'])
#     print('Bounding Box:', entry['bounding_box'])
#     print()

# %%
test_result_df = test_df['title'].apply(lambda x: bounding_box(x))

# %%
test_result_df[0][10:15]
# Out:
# [{'text': '', 'bounding_box': [22, 527, 742, 558]},
#  {'text': '', 'bounding_box': [491, 615, 630, 633]},
#  {'text': '‘Smith', 'bounding_box': [24, 31, 61, 41]},
#  {'text': '&', 'bounding_box': [66, 31, 75, 41]},
#  {'text': 'Smith,', 'bounding_box': [81, 31, 122, 43]}]

# %%
def retrieve_bounding_box(df, bounding_boxes_lists):
    x = df['invoice_number']
    y = df['issue_date']
    z = df['total']
#     text_extraction_row = []
#     bounding_box_extraction_row = []
    # x, y, and z are pandas Series representing columns of DataFrame
    for index, row in zip(x.index, zip(x, y, z)):  #looping through each row
        bounding_boxes = bounding_boxes_lists[index]  #updating the bounding_boxes_lists on next loop
#         print(bounding_boxes)
#         target_list = [row[0], row[1], row[2]]  
    
        for bounding_box in bounding_boxes:  #result_df[0] is a list of dictionary
            box = bounding_box['bounding_box']
            text = bounding_box['text']
#             print(text)
            if (text == row[0]):
                df.at[index,'invoice_number_bbox'] = str(box)
            elif (text == row[1]):
                df.at[index,'issue_date_bbox'] = str(box)
            elif (text == row[2]):
                df.at[index,'total_bbox'] = str(box)
                
    return df

                
result = retrieve_bounding_box(test_df, test_result_df)

# if result:
#     df = result
#     print(df.head())
# Out:
# /tmp/ipykernel_47/2327172474.py:22: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2200, 3010, 2310, 3041]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index,'total_bbox'] = str(box)

# %%
test_df.head()
# Out:
#   invoice_number   invoice_number_bbox  issue_date issue_date_bbox      total  \
# 0          22011  [688, 191, 739, 206]  01/08/2020             NaN     436.45
# 1        4631508  [785, 162, 846, 194]  13/05/2013             NaN    1445.99
# 2            NaN                   NaN  05/02/2022             NaN        NaN
# 3     To00000001  [323, 120, 408, 148]  10/10/2020             NaN  712000.00
# 4            NaN                   NaN  19/11/2020             NaN    7000.00
#
#   total_bbox                                              table  \
# 0        NaN  Date Services Hours Rates Amount\n08/01/2020 A...
# 1        NaN  Line No_ Line No_ Description Shipped (USD) (U...
# 2        NaN                                                NaN
# 3        NaN  ITEM NAME QTy PRICE{ DISCOUNT/ GST AMOUNT UNIT...
# 4        NaN  Particulars Quantity Rate Amount\nRepairs and ...
#
#                                 title
# 0                        mceclip2.png
# 1                              p1.jpg
# 2  Commercial-Invoice-Template-19.jpg
# 3                   image-414 (1).png
# 4                 service-invoice.jpg

# %%
test_df
# Out:
#          invoice_number     invoice_number_bbox  issue_date  \
# 0                 22011    [688, 191, 739, 206]  01/08/2020
# 1               4631508    [785, 162, 846, 194]  13/05/2013
# 2                   NaN                     NaN  05/02/2022
# 3            To00000001    [323, 120, 408, 148]  10/10/2020
# 4                   NaN                     NaN  19/11/2020
# 5           C1-10012014                     NaN  10/07/2014
# 6              BS 10009                     NaN   11/6/2013
# 7                   NaN                     NaN  14/09/2017
# 8               MAX1234                     NaN  19/11/2020
# 9                   NaN                     NaN  07/08/2012
# 10                 1227  [1002, 334, 1045, 349]   10/9/2020
# 11                    1                     NaN  06/07/2012
# 12             GE/3847/    [630, 113, 688, 126]  10/10/2020
# 13               982093     [80, 130, 133, 141]         NaN
# 14               US-001                     NaN  11/02/2019
# 15                  100    [173, 562, 190, 571]  27/02/2014
# 16                  NaN                     NaN  09/26/2018
# 17                 0001    [340, 448, 366, 457]  10/22/2020
# 18      GE/3847/20-2013                     NaN  10/10/2020
# 19                  NaN                     NaN     04/2020
# 20                    8    [593, 205, 605, 214]  01/03/2017
# 21           GSOOOOOOO1                     NaN  01/01/2008
# 22      KBM/15-16/50229                     NaN  31/08/2015
# 23                   21     [99, 339, 125, 358]  05/01/2021
# 24          2022/000323    [486, 171, 554, 179]   july 2022
# 25           SOtt306386  [1672, 526, 1805, 543]         NaN
# 26  JC Waa 0-1011-011SU                     NaN  06/12/2010
# 27                00121                     NaN  08/04/2015
# 28                  NaN                     NaN  19/11/2020
# 29                  NaN                     NaN  18/07/2022
# 30                  NaN                     NaN  14/04/2021
# 31  CIV-000676 000007-1                     NaN  30/11/2019
# 32           B202001676                     NaN  07/03/2020
# 33             CRM12345                     NaN  20/09/2012
# 34                  001    [244, 461, 267, 471]  15/10/2018
# 35                   48    [527, 566, 556, 586]  18/12/2014
# 36                30037                     NaN  17/03/2017
# 37              2017-40      [779, 82, 840, 95]  20/07/2017
# 38            0219-0001    [223, 466, 309, 492]  03/07/2015
# 39             DB-12657                     NaN  18/06/2017
# 40             71912018    [687, 243, 737, 252]  07/09/2015
#
#              issue_date_bbox      total                total_bbox  \
# 0                        NaN     436.45                       NaN
# 1                        NaN    1445.99                       NaN
# 2                        NaN        NaN                       NaN
# 3                        NaN  712000.00                       NaN
# 4                        NaN    7000.00                       NaN
# 5                        NaN   80000.00                       NaN
# 6       [686, 239, 745, 249]     120.00                       NaN
# 7                        NaN     918.00  [2200, 3010, 2310, 3041]
# 8                        NaN   93000.00                       NaN
# 9                        NaN      39.65                       NaN
# 10       [25, 733, 104, 746]   2,231.96                       NaN
# 11                       NaN    2407.00                       NaN
# 12      [540, 113, 609, 126]    3600.00                       NaN
# 13                       NaN    2112.25                       NaN
# 14                       NaN     154.06                       NaN
# 15                       NaN     635.90                       NaN
# 16        [33, 357, 87, 365]     200.00                       NaN
# 17                       NaN    5475.00                       NaN
# 18                       NaN   10440.00                       NaN
# 19                       NaN        NaN                       NaN
# 20                       NaN     510.60                       NaN
# 21                       NaN    5467.50                       NaN
# 22    [1134, 343, 1286, 384]  310693.00  [1274, 1325, 1388, 1358]
# 23                       NaN     775.00                       NaN
# 24                       NaN    5141.90                       NaN
# 25                       NaN    4763.45                       NaN
# 26  [2193, 3034, 2378, 3078]      64260                       NaN
# 27                       NaN     270.00                       NaN
# 28                       NaN   62000.00                       NaN
# 29                       NaN    2860.00                       NaN
# 30                       NaN    1010.00                       NaN
# 31                       NaN  321113.52                       NaN
# 32                       NaN      15576    [713, 1967, 751, 1978]
# 33                       NaN  54,435.50                       NaN
# 34                       NaN      52550                       NaN
# 35      [529, 616, 671, 636]     121.00                       NaN
# 36                       NaN    8383.00                       NaN
# 37                       NaN    4899.36      [807, 858, 860, 869]
# 38                       NaN      70.00  [1136, 1444, 1181, 1457]
# 39                       NaN   50340.00                       NaN
# 40                       NaN    5349.85                       NaN
#
#                                                 table  \
# 0   Date Services Hours Rates Amount\n08/01/2020 A...
# 1   Line No_ Line No_ Description Shipped (USD) (U...
# 2                                                 NaN
# 3   ITEM NAME QTy PRICE{ DISCOUNT/ GST AMOUNT UNIT...
# 4   Particulars Quantity Rate Amount\nRepairs and ...
# 5   DESCRIPTION QUANTITY TOTAL PRICE\nDOORS AND WI...
# 6   Product Price Quantity Line Total\nFlying Ninj...
# 7   Unit Item Price VAT Total\nSM-NO5OFZKABTU Sams...
# 8   Description Goods Quantity Rate Amount\nAsus 1...
# 9                                                 NaN
# 10  DATE EMPLOYEE DESCRIPTION HOURS RATE AMOUNT\n9...
# 11  QUANTITY DESCRIPTION UNIT PRICE AMOUNT\n120 Wi...
# 12  ITEM NAME HSN/SAC QTY PRICE / DISCOUNT/ GST AM...
# 13  DESCRIPTION QTY. PRICE TOTAL Web Design $ 200....
# 14  Qty Description Unit Price Amount\nFront and r...
# 15  Product Quantity Unit price Subtotal\nAppled i...
# 16  CODE DESCRIPTION UNIT RATE AMOUNT INLAND FREIG...
# 17  Description Quantity Unit Price Cost RXT-1 (Is...
# 18  ITEM NAME HSN/SAC QTY P RICE / DISCOUNT/ GSt A...
# 19                                                NaN
# 20  DESCRIPTION QUANTITY PRICE SALES TAX AMOUNT\nB...
# 21  Product Cost Total description S500.00 15% S42...
# 22  MODEL Product Description Amount NANO TWIST XT...
# 23  Description of Goods Tariff Code Country of Or...
# 24  Product Price Quantity Tax rate VAT Total Bean...
# 25  Art number Description HTS Code Country of Ori...
# 26  Fart NalJab Cadc Narbolars Type VaM Q4 Rale Rs...
# 27  Description Qty Unit Price Amount\nBrochure De...
# 28  Descnptior Quant Ancunt\nAsus 16.6 inch Monito...
# 29  ITEM NAME UNITS RATE TOTAL\nItem name 3450.00 ...
# 30  Description Amount\nDJ & MC Performance $200.0...
# 31  ITEM DESCRIPTION QUANTITY SALES PRICE DISCOUNT...
# 32  S.No_ Parts/OP code Part Labor Description HSN...
# 33  Quantity Description Unit Price Ext Price\n2,8...
# 34  DESCRIPTION HoURS RATE TOTAL WEDDING PHOTOSHOO...
# 35  Product Quantity Price Simple product €100.00 ...
# 36  Item Number / Description Quantity Quantity Pr...
# 37  No_ Name Qty Rate Disc. Amount Amt Amt Amt Ces...
# 38  Quantity Item Description Vendor Unit Price To...
# 39  Code Descnolion Cf Scods Urit Fice AMounz Duan...
# 40  Description Quantity Rate Options Total In-fli...
#
#                                                 title
# 0                                        mceclip2.png
# 1                                              p1.jpg
# 2                  Commercial-Invoice-Template-19.jpg
# 3                                   image-414 (1).png
# 4                                 service-invoice.jpg
# 5                       commercial-invoice-sample.png
# 6                              07_Invoice_Example.png
# 7                                 Samsung Invoice.jpg
# 8                               comercial-invoice.jpg
# 9                e1a0ba8226a03551145610bd34968cc5.jpg
# 10                                 Hourly_Invoice.png
# 11                     creating-invoices-on-excel.png
# 12                                       image-75.png
# 13  cyan-modern-invoice-sample-design-template-e32...
# 14           invoice-template-us-cool-waves-750px.png
# 15  586a7988dc847bbaf934469ddb58773e--invoice-temp...
# 16                    commercial-invoice-template.png
# 17      6NOC3qZ088oHYz6Bi3l7Mv1PvzFBgi6Z1DFnRpU5.jpeg
# 18                                       image-66.png
# 19  Nexon EV case Tata Power  Installation Report ...
# 20                                        invoice.png
# 21                                  Invoice_Item1.jpg
# 22                                    Tax Invoice.jpg
# 23                                file-8hNyTh6zgW.png
# 24  PDF-Invoices-Sample-invoice-with-VAT-itemized-...
# 25               Commercial-Invoice-2.1_1_ysej-7r.jpg
# 26                             120101207_10184901.jpg
# 27                                       excel-ss.png
# 28                                  delivery-note.jpg
# 29  62d834455e768e8073428f65_project-management-in...
# 30  dj-invoice-template-53096e98fc70ac1da9440ca933...
# 31                       paginated-report-invoice.png
# 32                                        Service.jpg
# 33              Invoices_Final_Invoice_Non_Boiler.jpg
# 34                     Invoice Sample Photography.jpg
# 35                  SampleInvoice_Original-scaled.jpg
# 36                                 01AR_print_inv.jpg
# 37                    Sample-GST-Invoice-956x1024.png
# 38                           racial-labor-invoice.png
# 39                    contoh-commercial-invoice-4.png
# 40                                 sample-invoice.png
